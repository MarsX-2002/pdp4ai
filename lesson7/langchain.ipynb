# %% [markdown]
# Langchain
#
# 1. combination of LLMs for specific tasks
# 2. Embeddings for search, semantic match
# 3. RAG (search phrase from company documents), chunk of setences in vector DB, position of chunks in vector DB
# 4. Image gen, Audio grn
# 5. islamic bank learn in malaysia -> implement in traditional banks (banks need speacialist who understand islamic bank, and can build -> islamic bank service)

# %%
# Langchain
